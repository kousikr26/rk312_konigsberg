# %%
import pandas as pd
import plotly as py
import plotly.graph_objects as go

# %%
towers=pd.read_csv('./data/towers_min.csv',index_col=0)
calls=pd.read_csv('./data/data.csv')

# %%
df=pd.merge(calls,towers,on='TowerID')

# %%
people=dict(type='scattermapbox',lat=df['lat'],lon=df['lon'],mode='markers',)
go.Figure(people,layout={
    'mapbox_style':'open-street-map',
    
})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-031e699e00f0> in <module>
#       1 people=dict(type='scattermapbox',lat=df['lat'],lon=df['lon'],mode='markers',)
# ----> 2 go.Figure(people,layout={
#       3     'mapbox_style':'open-street-map',
#       4     'zoom':14
#       5 })
#
# /usr/lib/python3/dist-packages/plotly/graph_objs/_figure.py in __init__(self, data, layout, frames, skip_invalid, **kwargs)
#     606             is invalid AND skip_invalid is False
#     607         """
# --> 608         super(Figure, self).__init__(data, layout, frames, skip_invalid, **kwargs)
#     609
#     610     def add_area(
#
# /usr/lib/python3/dist-packages/plotly/basedatatypes.py in __init__(self, data, layout_plotly, frames, skip_invalid, **kwargs)
#     196
#     197         # ### Import Layout ###
# ...

# %%
go.Figure(data=people)

# %%
go.Figure(data=people)
